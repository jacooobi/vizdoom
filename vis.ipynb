# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./training.csv')
df = df['loss']
df = df[df > 0]
df.head(n=5)
# Out:
# 0    1.017722
# 1    1.022666
# 2    1.010836
# 3    0.998676
# 4    0.994018
# Name: loss, dtype: float64

# %%
df[::30].plot()

# %%
reward_df = pd.read_csv('./rewards.csv')
reward_df = reward_df['reward']
reward_df = reward_df[reward_df > 0]
reward_df.head(n=5)
# Out:
# 0    505.0
# 1    370.0
# 2    512.5
# 3    647.5
# 4    782.5
# Name: reward, dtype: float64

# %%
reward_df[::30].plot()
